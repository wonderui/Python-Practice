# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
plt.plot(np.arange(10))

# %%
fig = plt.figure()

# %%
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)

# %%
fig

# %%
plt.plot([1.5, 3.5, -2, 1.6])

# %%
ax1.plot(np.random.randn(50).cumsum(), 'k--')
ax2.hist(randn(100), bins=20, color='k', alpha=0.3)
ax3.scatter(np.arange(30), np.arange(30) + 3 * randn(30))

# %%
fig

# %%
fig, axes = plt.subplots(2, 3)

# %%
axes
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1119e4a20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1113aa2e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1113a1470>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11127e978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1114c0438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11140ca58>]], dtype=object)

# %%
fig, axes = plt.subplots(2, 2, sharex=True, sharey=True)
for i in range(2):
    for j in range(2):
        axes[i, j].hist(randn(500), bins=50, color='red', alpha=0.5) # alpha is transparency!
plt.subplots_adjust(wspace=0, hspace=0)
